# %%
import geopandas as gpd
df = gpd.read_file('/data/acker/ALA/NA/NAv5_GWRPM25_mean2015-2017_49011.shp')
df
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID   NAME      NAMELSAD  \
# 0      49      011  01448020  0500000US49011  49011  Davis  Davis County
#
#   STUSPS STATE_NAME LSAD      ALAND     AWATER  maxGWRPM25  meanGWRPM2  \
# 0     UT       Utah   06  774579558  870614815   52.433334   10.213505
#
#    p90GWRPM25                                           geometry
# 0   22.213333  POLYGON ((-1364257.425 2127151.833, -1342353.4...
