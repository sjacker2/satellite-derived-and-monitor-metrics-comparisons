# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from shapely.geometry import Point
df = gpd.read_file('/data/acker/ALA/paper2/washu_2021-2023_merged.shp')
df
# Out:
#      index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  Design Val  \
# 0        0  02090  14.333333      02      090          1  02_090        12.1
# 1        1  06063  14.200000      06      063          2  06_063        14.0
# 2        2  06107  12.933334      06      107          4  06_107        15.7
# 3        3  06023  12.633334      06      023          5  06_023         6.9
# 4        4  06029  12.599999      06      029          6  06_029        16.2
# ..     ...    ...        ...     ...      ...        ...     ...         ...
# 531    531  02020   4.133333      02      020       3118  02_020         5.1
# 532    532  02110   3.900000      02      110       3128  02_110         4.6
# 533    533  15001   3.633333      15      001       3133  15_001         4.4
# 534    534  15009   3.556667      15      009       3136  15_009         4.0
# 535    535  15003   3.100000      15      003       3141  15_003         3.7
#
#                                               geometry
# 0    POLYGON ((-148.66326 64.59079, -148.64821 64.5...
# 1    POLYGON ((-121.49703 40.43702, -121.49487 40.4...
# 2    POLYGON ((-119.56647 36.49434, -119.56366 36.4...
# 3    POLYGON ((-124.4086 40.4432, -124.39664 40.462...
# 4    POLYGON ((-120.19437 35.78936, -120.00308 35.7...
# ..                                                 ...
# 531  MULTIPOLYGON (((-150.07348 61.15834, -150.0691...
# 532  MULTIPOLYGON (((-134.66932 58.33327, -134.6675...
# 533  POLYGON ((-156.06147 19.72813, -156.06076 19.7...
# 534  MULTIPOLYGON (((-156.69742 20.91637, -156.6957...
# 535  MULTIPOLYGON (((-157.65982 21.32857, -157.6588...
#
# [536 rows x 9 columns]

# %%
df = df.rename(columns={'Design Val':'Design Value'})

# %%
#upload shapefile of U.S. counties
counties = gpd.read_file('/data/acker/shapefiles/cb_2020_us_county_500k.shp')

# %%
# List of state abbreviations for CONUS, Alaska (AK), and Hawaii (HI)
states_to_include = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'DC',
    'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS',
    'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK',
    'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV',
    'WI', 'WY'
]

# Filter counties to only include rows where STUSPS is in the specified list
counties_conus = counties[counties['STUSPS'].isin(states_to_include)]

# Display the filtered counties
counties_conus
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME  \
# 0         13      031  00350302  0500000US13031  13031    Bulloch
# 1         13      121  01694833  0500000US13121  13121     Fulton
# 2         13      179  00357095  0500000US13179  13179    Liberty
# 3         13      189  00348794  0500000US13189  13189   McDuffie
# 4         13      213  01688005  0500000US13213  13213     Murray
# ...      ...      ...       ...             ...    ...        ...
# 3228      41      049  01135860  0500000US41049  41049     Morrow
# 3229      21      073  00516883  0500000US21073  21073   Franklin
# 3230      17      201  01785216  0500000US17201  17201  Winnebago
# 3231      17      123  00424260  0500000US17123  17123   Marshall
# 3232      37      185  01008593  0500000US37185  37185     Warren
#
#               NAMELSAD STUSPS      STATE_NAME LSAD       ALAND     AWATER  \
# 0       Bulloch County     GA         Georgia   06  1750735216   32827779
# 1        Fulton County     GA         Georgia   06  1364133162   19666288
# 2       Liberty County     GA         Georgia   06  1337654102  222884791
# 3      McDuffie County     GA         Georgia   06   666590014   23114032
# 4        Murray County     GA         Georgia   06   892235145    5719644
# ...                ...    ...             ...  ...         ...        ...
# 3228     Morrow County     OR          Oregon   06  5259046087   44372730
# 3229   Franklin County     KY        Kentucky   06   538312209   10786432
# 3230  Winnebago County     IL        Illinois   06  1328792556   15873993
# 3231   Marshall County     IL        Illinois   06  1001843226   30364348
# 3232     Warren County     NC  North Carolina   06  1112117461   38615564
#
#                                                geometry
# 0     POLYGON ((-82.02684 32.55516, -82.02527 32.558...
# 1     POLYGON ((-84.84931 33.51318, -84.84429 33.514...
# 2     POLYGON ((-81.8244 32.01488, -81.81338 32.0162...
# 3     POLYGON ((-82.64852 33.60838, -82.64409 33.606...
# 4     POLYGON ((-84.94434 34.68004, -84.9431 34.6804...
# ...                                                 ...
# 3228  POLYGON ((-120.00631 45.27648, -120.00556 45.3...
# 3229  POLYGON ((-85.02426 38.13059, -85.02299 38.131...
# 3230  POLYGON ((-89.40142 42.50043, -89.37175 42.500...
# 3231  POLYGON ((-89.63869 40.98691, -89.63868 40.988...
# 3232  POLYGON ((-78.32391 36.54381, -78.313 36.54388...
#
# [3143 rows x 13 columns]

# %%
counties_conus = counties_conus.drop(["COUNTYNS", 'NAMELSAD', 'LSAD', 'ALAND', 'AWATER', 'AFFGEOID'], axis=1)

# %%
counties_conus = counties_conus.to_crs(df.crs)

# %%
merged_df = df

# %%
merged_df['diff'] =  merged_df['PM25_90th'] - merged_df['Design Value']
merged_df['diff'].describe()
# Out:
# count    536.000000
# mean       0.064832
# std        1.227862
# min       -5.333334
# 25%       -0.533333
# 50%        0.133334
# 75%        0.775000
# max        5.733334
# Name: diff, dtype: float64

# %%
# Define threshold
threshold = 9.0

# Function to classify each row
def classify(row):
    cdv = row['Design Value']
    cdve = row['PM25_90th']
    if cdv > threshold and cdve > threshold:
        return 'TP'
    elif cdv > threshold and cdve <= threshold:
        return 'FN'
    elif cdv <= threshold and cdve > threshold:
        return 'FP'
    else:
        return 'TN'

# Apply the classification
merged_df['classification'] = merged_df.apply(classify, axis=1)

# Print counts
print(merged_df['classification'].value_counts())

# Optional: filter into separate DataFrames
TP = merged_df[merged_df['classification'] == 'TP']
FP = merged_df[merged_df['classification'] == 'FP']
FN = merged_df[merged_df['classification'] == 'FN']
TN = merged_df[merged_df['classification'] == 'TN']
print('TP:',len(TP))
print('FP:',len(FP))
print('FN:', len(FN))
print('TN:',len(TN))
# Out:
# classification
# TN    376
# TP     63
# FN     52
# FP     45
# Name: count, dtype: int64
# TP: 63
# FP: 45
# FN: 52
# TN: 376

# %%
FN['diff'].describe()
# Out:
# count    52.000000
# mean     -1.683333
# std       1.192921
# min      -5.333334
# 25%      -2.266667
# 50%      -1.416667
# 75%      -0.612500
# max      -0.133334
# Name: diff, dtype: float64

# %%
# Define threshold
threshold = 9.0

# Create a copy to avoid modifying original
FN_sensitivity = FN.copy()

# Define classification function
def classify(cdv, cdve, threshold=threshold):
    if cdv > threshold and cdve > threshold:
        return "TP"
    elif cdv <= threshold and cdve <= threshold:
        return "TN"
    elif cdv <= threshold and cdve > threshold:
        return "FP"
    else:  # cdv > threshold and cdve <= threshold
        return "FN"

# Perturbation values
cdv_changes = [-0.5, 0, +0.5]
cdve_changes = [-0.5, 0, +0.5]

# Apply all combinations
for delta_cdv in cdv_changes:
    for delta_cdve in cdve_changes:
        col_name = f"class_cdv{delta_cdv:+.1f}_cdve{delta_cdve:+.1f}"
        FN_sensitivity[col_name] = FN_sensitivity.apply(
            lambda row: classify(row['Design Value'] + delta_cdv,
                                 row['PM25_90th'] + delta_cdve),
            axis=1
        )

# Summarize results
summary = {}
for delta_cdv in cdv_changes:
    for delta_cdve in cdve_changes:
        col_name = f"class_cdv{delta_cdv:+.1f}_cdve{delta_cdve:+.1f}"
        counts = FN_sensitivity[col_name].value_counts()
        summary[col_name] = counts

# Print summary nicely
for perturbation, counts in summary.items():
    print(f"\nPerturbation: {perturbation}")
    print(counts)
# Out:
# Perturbation: class_cdv-0.5_cdve-0.5
# class_cdv-0.5_cdve-0.5
# FN    27
# TN    25
# Name: count, dtype: int64
#
# Perturbation: class_cdv-0.5_cdve+0.0
# class_cdv-0.5_cdve+0.0
# FN    27
# TN    25
# Name: count, dtype: int64
#
# Perturbation: class_cdv-0.5_cdve+0.5
# class_cdv-0.5_cdve+0.5
# FN    17
# FP    14
# TN    11
# TP    10
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.0_cdve-0.5
# class_cdv+0.0_cdve-0.5
# FN    52
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.0_cdve+0.0
# class_cdv+0.0_cdve+0.0
# FN    52
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.0_cdve+0.5
# class_cdv+0.0_cdve+0.5
# FN    28
# TP    24
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.5_cdve-0.5
# class_cdv+0.5_cdve-0.5
# FN    52
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.5_cdve+0.0
# class_cdv+0.5_cdve+0.0
# FN    52
# Name: count, dtype: int64
#
# Perturbation: class_cdv+0.5_cdve+0.5
# class_cdv+0.5_cdve+0.5
# FN    28
# TP    24
# Name: count, dtype: int64

# %%
# Define threshold and margin
threshold = 9.0
margin = 0.5  # Adjust to 1.0 for a ±1.0 µg/m³ range

# Calculate the absolute difference between CDVE and the threshold
FN['cdve_diff'] = abs(FN['PM25_90th'] - threshold)

# Identify near-miss counties
FN['near_miss1'] = FN['cdve_diff'] <= margin

# Optional: Count the number of near-miss counties
num_near_miss = FN['near_miss1'].sum()
print(f"Number of near-miss counties (±{margin} µg/m³): {num_near_miss}")
# Define threshold and margin
threshold = 9.0
margin = 0.5  # Adjust to 1.0 for a ±1.0 µg/m³ range

# Calculate the absolute difference between CDV and the threshold
FN['cdv_diff'] = abs(FN['Design Value'] - threshold)

# Identify near-miss counties
FN['near_miss2'] = FN['cdv_diff'] <= margin

# Optional: Count the number of near-miss counties
num_near_miss = FN['near_miss2'].sum()
print(f"Number of near-miss counties (±{margin} µg/m³): {num_near_miss}")
both = FN[(FN['near_miss1'] == True) & (FN['near_miss2'] == True)]
both['diff'].describe()
# Out:
# Number of near-miss counties (±0.5 µg/m³): 24
# Number of near-miss counties (±0.5 µg/m³): 25
# /home/acker/miniconda3/envs/tempo/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/acker/miniconda3/envs/tempo/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/acker/miniconda3/envs/tempo/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/acker/miniconda3/envs/tempo/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# count    14.000000
# mean     -0.498810
# std       0.231722
# min      -0.933333
# 25%      -0.591667
# 50%      -0.541667
# 75%      -0.283334
# max      -0.133334
# Name: diff, dtype: float64

# %%
both
# Out:
#      index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  \
# 114    114  26081   8.966666      26      081        187  26_081
# 115    115  22121   8.966666      22      121        187  22_121
# 116    116  28035   8.966666      28      035        187  28_035
# 119    119  37119   8.933333      37      119        196  37_119
# 125    125  18141   8.866667      18      141        210  18_141
# 131    131  47093   8.833333      47      093        221  47_093
# 134    134  34039   8.833333      34      039        221  34_039
# 137    137  13021   8.800000      13      021        236  13_021
# 146    146  49035   8.750000      49      035        260  49_035
# 148    148  26161   8.733334      26      161        261  26_161
# 151    151  05139   8.700000      05      139        273  05_139
# 155    155  19045   8.666667      19      045        282  19_045
# 163    163  18167   8.633333      18      167        298  18_167
# 172    172  48203   8.566667      48      203        329  48_203
#
#      Design Value                                           geometry  \
# 114           9.3  POLYGON ((-85.79061 43.20987, -85.79056 43.226...
# 115           9.1  POLYGON ((-91.48156 30.49742, -91.48173 30.511...
# 116           9.2  POLYGON ((-89.45162 31.43403, -89.44455 31.434...
# 119           9.2  POLYGON ((-81.05803 35.07319, -81.05768 35.078...
# 125           9.4  POLYGON ((-86.52648 41.65768, -86.52601 41.672...
# 131           9.1  POLYGON ((-84.27347 35.93928, -84.27155 35.942...
# 134           9.4  POLYGON ((-74.46329 40.59919, -74.45988 40.600...
# 137           9.4  POLYGON ((-83.892 32.83254, -83.89192 32.84835...
# 146           9.3  POLYGON ((-112.26022 40.76909, -112.19598 40.8...
# 148           9.3  POLYGON ((-84.13406 42.16925, -84.13365 42.177...
# 151           9.3  POLYGON ((-92.98633 33.0977, -92.98591 33.1163...
# 155           9.2  POLYGON ((-90.89894 41.91853, -90.89807 41.920...
# 163           9.5  POLYGON ((-87.62048 39.30713, -87.61261 39.308...
# 172           9.5  POLYGON ((-94.70215 32.45613, -94.70197 32.467...
#
#          diff classification  cdv_above  cdve_above  near_miss_cdv  \
# 114 -0.333334             FN       True       False           True
# 115 -0.133334             FN       True       False           True
# 116 -0.233334             FN       True       False           True
# 119 -0.266667             FN       True       False           True
# 125 -0.533333             FN       True       False           True
# 131 -0.266667             FN       True       False           True
# 134 -0.566667             FN       True       False           True
# 137 -0.600000             FN       True       False           True
# 146 -0.550000             FN       True       False           True
# 148 -0.566666             FN       True       False           True
# 151 -0.600000             FN       True       False           True
# 155 -0.533333             FN       True       False           True
# 163 -0.866667             FN       True       False           True
# 172 -0.933333             FN       True       False           True
#
#      near_miss_cdve  cdve_diff  near_miss1  cdv_diff  near_miss2
# 114            True   0.033334        True       0.3        True
# 115            True   0.033334        True       0.1        True
# 116            True   0.033334        True       0.2        True
# 119            True   0.066667        True       0.2        True
# 125            True   0.133333        True       0.4        True
# 131            True   0.166667        True       0.1        True
# 134            True   0.166667        True       0.4        True
# 137            True   0.200000        True       0.4        True
# 146            True   0.250000        True       0.3        True
# 148            True   0.266666        True       0.3        True
# 151            True   0.300000        True       0.3        True
# 155            True   0.333333        True       0.2        True
# 163            True   0.366667        True       0.5        True
# 172            True   0.433333        True       0.5        True

# %%
import matplotlib.pyplot as plt
import numpy as np

# Determine range of diff values
min_diff = FN['diff'].min()
max_diff = FN['diff'].max()

# Create bin edges spaced 0.5 apart
bins = np.arange(np.floor(min_diff), np.ceil(max_diff) + 0.5, 0.5)

# Plot
plt.figure(figsize=(8, 5))
plt.hist(FN['diff'], bins=bins, color='#fe9bfe', edgecolor='black')
plt.rcParams["font.family"] = "serif"

plt.xlabel('Difference (CDVE – CDV) (µg/m³)', fontsize=16)
plt.ylabel('', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('(d) False Negatives', fontsize=18)
plt.grid(False)
plt.xlim(-6, 6)
plt.ylim(0,14)
plt.rcParams["font.family"] = "serif"
plt.tight_layout()
plt.show()

# %%
# Calculate histogram
counts, bin_edges = np.histogram(FN['diff'], bins=bins)

# Print counts per bin
for i in range(len(counts)):
    print(f"{bin_edges[i]:.1f} to {bin_edges[i+1]:.1f} µg/m³: {counts[i]} counties")
# Out:
# 0.0 to 0.5 µg/m³: 11 counties
# 0.5 to 1.0 µg/m³: 9 counties
# 1.0 to 1.5 µg/m³: 8 counties
# 1.5 to 2.0 µg/m³: 6 counties
# 2.0 to 2.5 µg/m³: 6 counties
# 2.5 to 3.0 µg/m³: 3 counties
# 3.0 to 3.5 µg/m³: 1 counties
# 3.5 to 4.0 µg/m³: 0 counties
# 4.0 to 4.5 µg/m³: 0 counties
# 4.5 to 5.0 µg/m³: 0 counties
# 5.0 to 5.5 µg/m³: 0 counties
# 5.5 to 6.0 µg/m³: 1 counties

# %%
unc = gpd.read_file('/data/acker/ALA/paper2/GL_uncertainty_2021-2023_grids.shp')
unc
# Out:
#                   unc        lat        lon  \
# 0           24.247866  10.005000 -85.724998
# 1           23.823935  10.005000 -85.714996
# 2           23.823935  10.005000 -85.705002
# 3           25.163263  10.005000 -85.695000
# 4           25.460693  10.005000 -85.684998
# ...               ...        ...        ...
# 25818367  1004.444397  67.985001 -50.055000
# 25818368  1023.333313  67.985001 -50.044998
# 25818369  1023.333313  67.985001 -50.035000
# 25818370  1029.444458  67.985001 -50.025002
# 25818371  1032.777710  67.985001 -50.014999
#
#                                                    geometry
# 0         POLYGON ((-85.725 10.005, -85.725 10.015, -85....
# 1         POLYGON ((-85.715 10.005, -85.715 10.015, -85....
# 2         POLYGON ((-85.705 10.005, -85.705 10.015, -85....
# 3         POLYGON ((-85.695 10.005, -85.695 10.015, -85....
# 4         POLYGON ((-85.685 10.005, -85.685 10.015, -85....
# ...                                                     ...
# 25818367  POLYGON ((-50.055 67.985, -50.055 67.995, -50....
# 25818368  POLYGON ((-50.045 67.985, -50.045 67.995, -50....
# 25818369  POLYGON ((-50.035 67.985, -50.035 67.995, -50....
# 25818370  POLYGON ((-50.025 67.985, -50.025 67.995, -50....
# 25818371  POLYGON ((-50.015 67.985, -50.015 67.995, -50....
#
# [25818372 rows x 4 columns]

# %%
unc_counties = gpd.sjoin(unc, FN, how='inner', predicate='intersects')
unc_counties
# Out:
#                 unc        lat         lon  \
# 2073941   61.251465  27.584999  -82.764999
# 2075748   59.071728  27.594999  -82.764999
# 2077552   69.342682  27.605000  -82.735001
# 2079356   68.451859  27.615000  -82.735001
# 2079357   67.446518  27.615000  -82.724998
# ...             ...        ...         ...
# 11657713  43.418961  48.994999 -114.114998
# 11657714  42.679043  48.994999 -114.105003
# 11657715  41.871250  48.994999 -114.095001
# 11657716  41.641079  48.994999 -114.084999
# 11657717  41.526928  48.994999 -114.074997
#
#                                                    geometry  index_right0  \
# 2073941   POLYGON ((-82.765 27.585, -82.765 27.595, -82....            73
# 2075748   POLYGON ((-82.765 27.595, -82.765 27.605, -82....            73
# 2077552   POLYGON ((-82.735 27.605, -82.735 27.615, -82....            78
# 2079356   POLYGON ((-82.735 27.615, -82.735 27.625, -82....            78
# 2079357   POLYGON ((-82.725 27.615, -82.725 27.625, -82....            78
# ...                                                     ...           ...
# 11657713  POLYGON ((-114.115 48.995, -114.115 49.005, -1...            64
# 11657714  POLYGON ((-114.105 48.995, -114.105 49.005, -1...            64
# 11657715  POLYGON ((-114.095 48.995, -114.095 49.005, -1...            64
# 11657716  POLYGON ((-114.085 48.995, -114.085 49.005, -1...            64
# 11657717  POLYGON ((-114.075 48.995, -114.075 49.005, -1...            64
#
#           index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  \
# 2073941      73  12057   9.366666      12      057        112  12_057
# 2075748      73  12057   9.366666      12      057        112  12_057
# 2077552      78  12103   9.300000      12      103        122  12_103
# 2079356      78  12103   9.300000      12      103        122  12_103
# 2079357      78  12103   9.300000      12      103        122  12_103
# ...         ...    ...        ...     ...      ...        ...     ...
# 11657713     64  30029   9.466666      30      029         98  30_029
# 11657714     64  30029   9.466666      30      029         98  30_029
# 11657715     64  30029   9.466666      30      029         98  30_029
# 11657716     64  30029   9.466666      30      029         98  30_029
# 11657717     64  30029   9.466666      30      029         98  30_029
#
#           Design Value      diff classification  cdve_diff  near_miss1  \
# 2073941            7.4  1.966666             FN   0.366666        True
# 2075748            7.4  1.966666             FN   0.366666        True
# 2077552            6.9  2.400000             FN   0.300000        True
# 2079356            6.9  2.400000             FN   0.300000        True
# 2079357            6.9  2.400000             FN   0.300000        True
# ...                ...       ...            ...        ...         ...
# 11657713           8.6  0.866666             FN   0.466666        True
# 11657714           8.6  0.866666             FN   0.466666        True
# 11657715           8.6  0.866666             FN   0.466666        True
# 11657716           8.6  0.866666             FN   0.466666        True
# 11657717           8.6  0.866666             FN   0.466666        True
#
#           cdv_diff  near_miss2
# 2073941        1.6       False
# 2075748        1.6       False
# 2077552        2.1       False
# 2079356        2.1       False
# 2079357        2.1       False
# ...            ...         ...
# 11657713       0.4        True
# 11657714       0.4        True
# 11657715       0.4        True
# 11657716       0.4        True
# 11657717       0.4        True
#
# [97519 rows x 19 columns]

# %%
unc_counties['unc'].describe()
# Out:
# count    97519.000000
# mean        42.857008
# std         14.898817
# min         25.561356
# 25%         35.353413
# 50%         40.321579
# 75%         46.393507
# max        599.433594
# Name: unc, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define bins and labels
bins = np.append(np.arange(25, 105, 5), [np.inf])
labels = [f"{int(bins[i])}" if bins[i+1] != np.inf else "100+" for i in range(len(bins)-1)]

import pandas as pd

# Create a binned column
unc_counties['unc_bin'] = pd.cut(unc_counties['unc'], bins=bins, labels=labels, right=False)

# Count how many in each bin
bin_counts = unc_counties['unc_bin'].value_counts().sort_index()

# Plot
plt.figure(figsize=(10, 5))
plt.bar(bin_counts.index.astype(str), bin_counts.values, width=1.0, color='#8E0EA5', edgecolor='black')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.ylim(0,90000)
plt.xlabel('', fontsize=16)
plt.ylabel('', fontsize=16)
plt.title('(b) False Negatives', fontsize=18)
#plt.xticks(rotation=45)
plt.rcParams["font.family"] = "serif"
plt.tight_layout()
plt.show()

# %%
import pandas as pd
dvs = pd.read_csv('/data/acker/EPA_DV/site_DVs_2021-2023.csv')
dvs
# Out:
#           State Name County Name                     CBSA Name  \
# 0            Alabama     Baldwin     Daphne-Fairhope-Foley, AL
# 1            Alabama        Clay
# 2            Alabama      DeKalb
# 3            Alabama      Etowah                   Gadsden, AL
# 4            Alabama   Jefferson         Birmingham-Hoover, AL
# ...              ...         ...                           ...
# 1055     Puerto Rico     Fajardo  San Juan-Carolina-Caguas, PR
# 1056     Puerto Rico     Guayama                   Guayama, PR
# 1057     Puerto Rico    Guaynabo  San Juan-Carolina-Caguas, PR
# 1058     Puerto Rico       Ponce                     Ponce, PR
# 1059  Virgin Islands    St Croix
#
#                              CSA Name  EPA Region  AQS Site ID  \
# 0          Mobile-Daphne-Fairhope, AL           4     10030010
# 1                                               4     10270001
# 2                                               4     10491003
# 3                                               4     10550010
# 4     Birmingham-Hoover-Talladega, AL           4     10730023
# ...                               ...         ...          ...
# 1055            San Juan-Carolina, PR           2    720530003
# 1056            San Juan-Carolina, PR           2    720570012
# 1057            San Juan-Carolina, PR           2    720610005
# 1058     Ponce-Coamo-Santa Isabel, PR           2    721130004
# 1059                                            2    780100012
#
#          Local Site Name  Site Latitude  Site Longitude  Valid DV   \
# 0      Fairhope, Alabama      30.497478      -87.880258        7.4
# 1                Ashland      33.284928      -85.803608        7.3
# 2             Crossville      34.288567      -85.969858        7.8
# 3     Gadsden C. College      33.988210      -85.992556        NaN
# 4       North Birmingham      33.553056      -86.815000        9.6
# ...                  ...            ...             ...        ...
# 1055             Fajardo      18.383983      -65.618888        NaN
# 1056                          17.955378      -66.162122        NaN
# 1057            Guaynabo      18.440095      -66.114460        NaN
# 1058    Residential Area      18.009558      -66.627249        NaN
# 1059                          17.712474      -64.784868        NaN
#
#       Invalid DV  2021 Annual Mean Value (µg/m3)  \
# 0            NaN                            7.28
# 1            NaN                            6.81
# 2            NaN                            7.75
# 3            8.8                            8.38
# 4            NaN                            9.71
# ...          ...                             ...
# 1055         7.1                            7.20
# 1056         5.6                            7.02
# 1057         7.5                            8.00
# 1058         6.7                            6.96
# 1059         6.4                            6.10
#
#       2022 Annual Mean Value (µg/m3)  2023 Annual Mean Value (µg/m3)
# 0                               7.33                            7.60
# 1                               6.89                            8.10
# 2                               6.86                            8.89
# 3                               8.20                            9.82
# 4                               9.00                           10.07
# ...                              ...                             ...
# 1055                            7.20                            6.86
# 1056                            4.17                             NaN
# 1057                            7.54                            7.06
# 1058                            6.74                            6.33
# 1059                            6.76                             NaN
#
# [1060 rows x 14 columns]

# %%
dvs.columns
# Out:
# Index(['State Name', 'County Name', 'CBSA Name', 'CSA Name', 'EPA Region',
#        'AQS Site ID', 'Local Site Name', 'Site Latitude', 'Site Longitude',
#        'Valid DV ', 'Invalid DV', '2021 Annual Mean Value (µg/m3)',
#        '2022 Annual Mean Value (µg/m3)', '2023 Annual Mean Value (µg/m3)'],
#       dtype='object')

# %%
import numpy as np
valid = dvs.dropna(subset=['Valid DV '])
valid
# Out:
#        State Name County Name                     CBSA Name  \
# 0         Alabama     Baldwin     Daphne-Fairhope-Foley, AL
# 1         Alabama        Clay
# 2         Alabama      DeKalb
# 4         Alabama   Jefferson         Birmingham-Hoover, AL
# 5         Alabama   Jefferson         Birmingham-Hoover, AL
# ...           ...         ...                           ...
# 1045      Wyoming    Sheridan                  Sheridan, WY
# 1047      Wyoming    Sublette
# 1050      Wyoming       Teton                Jackson, WY-ID
# 1051      Wyoming       Teton                Jackson, WY-ID
# 1053  Puerto Rico     Bayamon  San Juan-Carolina-Caguas, PR
#
#                              CSA Name  EPA Region  AQS Site ID  \
# 0          Mobile-Daphne-Fairhope, AL           4     10030010
# 1                                               4     10270001
# 2                                               4     10491003
# 4     Birmingham-Hoover-Talladega, AL           4     10730023
# 5     Birmingham-Hoover-Talladega, AL           4     10731005
# ...                               ...         ...          ...
# 1045                                            8    560330002
# 1047                                            8    560350101
# 1050                                            8    560391006
# 1051                                            8    560391013
# 1053            San Juan-Carolina, PR           2    720210010
#
#                                         Local Site Name  Site Latitude  \
# 0                                     Fairhope, Alabama      30.497478
# 1                                               Ashland      33.284928
# 2                                            Crossville      34.288567
# 4                                      North Birmingham      33.553056
# 5                                               Mcadory      33.331111
# ...                                                 ...            ...
# 1045                   Sheridan - Police Sta. Slam Site      44.815142
# 1047                                   Pinedale Gaseous      42.869824
# 1050                                  Jackson Slam Site      43.457760
# 1051  Yellowstone National Park - Old Faithful Snow ...      44.373056
# 1053                                            Bayamon      18.420089
#
#       Site Longitude  Valid DV   Invalid DV  2021 Annual Mean Value (µg/m3)  \
# 0         -87.880258        7.4         NaN                            7.28
# 1         -85.803608        7.3         NaN                            6.81
# 2         -85.969858        7.8         NaN                            7.75
# 4         -86.815000        9.6         NaN                            9.71
# 5         -87.003611        8.4         NaN                            8.18
# ...              ...        ...         ...                             ...
# 1045     -106.955933        7.0         NaN                            6.47
# 1047     -109.870760        3.7         NaN                            4.68
# 1050     -110.797990        3.1         NaN                            4.94
# 1051     -110.830833        4.0         NaN                            5.08
# 1053      -66.150615        6.7         NaN                            7.39
#
#       2022 Annual Mean Value (µg/m3)  2023 Annual Mean Value (µg/m3)
# 0                               7.33                            7.60
# 1                               6.89                            8.10
# 2                               6.86                            8.89
# 4                               9.00                           10.07
# 5                               8.02                            8.99
# ...                              ...                             ...
# 1045                            7.73                            6.75
# 1047                            3.09                            3.37
# 1050                            2.74                            1.71
# 1051                            4.06                            2.77
# 1053                            6.47                            6.34
#
# [808 rows x 14 columns]

# %%
valid['geometry'] = gpd.points_from_xy(valid['Site Longitude'], valid['Site Latitude'])
valid = gpd.GeoDataFrame(valid, geometry="geometry", crs="EPSG:4269")
valid
# Out:
# /tmp/ipykernel_5573/3099035182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['geometry'] = gpd.points_from_xy(valid['Site Longitude'], valid['Site Latitude'])
#        State Name County Name                     CBSA Name  \
# 0         Alabama     Baldwin     Daphne-Fairhope-Foley, AL
# 1         Alabama        Clay
# 2         Alabama      DeKalb
# 4         Alabama   Jefferson         Birmingham-Hoover, AL
# 5         Alabama   Jefferson         Birmingham-Hoover, AL
# ...           ...         ...                           ...
# 1045      Wyoming    Sheridan                  Sheridan, WY
# 1047      Wyoming    Sublette
# 1050      Wyoming       Teton                Jackson, WY-ID
# 1051      Wyoming       Teton                Jackson, WY-ID
# 1053  Puerto Rico     Bayamon  San Juan-Carolina-Caguas, PR
#
#                              CSA Name  EPA Region  AQS Site ID  \
# 0          Mobile-Daphne-Fairhope, AL           4     10030010
# 1                                               4     10270001
# 2                                               4     10491003
# 4     Birmingham-Hoover-Talladega, AL           4     10730023
# 5     Birmingham-Hoover-Talladega, AL           4     10731005
# ...                               ...         ...          ...
# 1045                                            8    560330002
# 1047                                            8    560350101
# 1050                                            8    560391006
# 1051                                            8    560391013
# 1053            San Juan-Carolina, PR           2    720210010
#
#                                         Local Site Name  Site Latitude  \
# 0                                     Fairhope, Alabama      30.497478
# 1                                               Ashland      33.284928
# 2                                            Crossville      34.288567
# 4                                      North Birmingham      33.553056
# 5                                               Mcadory      33.331111
# ...                                                 ...            ...
# 1045                   Sheridan - Police Sta. Slam Site      44.815142
# 1047                                   Pinedale Gaseous      42.869824
# 1050                                  Jackson Slam Site      43.457760
# 1051  Yellowstone National Park - Old Faithful Snow ...      44.373056
# 1053                                            Bayamon      18.420089
#
#       Site Longitude  Valid DV   Invalid DV  2021 Annual Mean Value (µg/m3)  \
# 0         -87.880258        7.4         NaN                            7.28
# 1         -85.803608        7.3         NaN                            6.81
# 2         -85.969858        7.8         NaN                            7.75
# 4         -86.815000        9.6         NaN                            9.71
# 5         -87.003611        8.4         NaN                            8.18
# ...              ...        ...         ...                             ...
# 1045     -106.955933        7.0         NaN                            6.47
# 1047     -109.870760        3.7         NaN                            4.68
# 1050     -110.797990        3.1         NaN                            4.94
# 1051     -110.830833        4.0         NaN                            5.08
# 1053      -66.150615        6.7         NaN                            7.39
#
#       2022 Annual Mean Value (µg/m3)  2023 Annual Mean Value (µg/m3)  \
# 0                               7.33                            7.60
# 1                               6.89                            8.10
# 2                               6.86                            8.89
# 4                               9.00                           10.07
# 5                               8.02                            8.99
# ...                              ...                             ...
# 1045                            7.73                            6.75
# 1047                            3.09                            3.37
# 1050                            2.74                            1.71
# 1051                            4.06                            2.77
# 1053                            6.47                            6.34
#
#                          geometry
# 0      POINT (-87.88026 30.49748)
# 1      POINT (-85.80361 33.28493)
# 2      POINT (-85.96986 34.28857)
# 4        POINT (-86.815 33.55306)
# 5      POINT (-87.00361 33.33111)
# ...                           ...
# 1045  POINT (-106.95593 44.81514)
# 1047  POINT (-109.87076 42.86982)
# 1050  POINT (-110.79799 43.45776)
# 1051  POINT (-110.83083 44.37306)
# 1053   POINT (-66.15062 18.42009)
#
# [808 rows x 15 columns]

# %%
merged_df_2 = gpd.sjoin(valid, FN, how="left", predicate="within")
# Count monitors per county (assuming counties have a unique ID, like 'GEOID' or 'county_name')
monitor_counts = merged_df_2.groupby("GEOID").size().reset_index(name='monitor_count')
monitor_counts
# Out:
#     GEOID  monitor_count
# 0   01113              1
# 1   04021              3
# 2   04023              1
# 3   05139              1
# 4   06013              2
# 5   06045              2
# 6   06071              5
# 7   06085              3
# 8   06101              1
# 9   13021              2
# 10  13245              1
# 11  13295              1
# 12  13303              1
# 13  16009              1
# 14  16059              1
# 15  16079              1
# 16  18141              1
# 17  18167              1
# 18  19045              2
# 19  20133              1
# 20  20209              1
# 21  21013              1
# 22  22121              1
# 23  26077              1
# 24  26081              1
# 25  26113              1
# 26  26161              1
# 27  28035              1
# 28  28049              2
# 29  30053              1
# 30  30063              2
# 31  34007              2
# 32  34039              2
# 33  37057              1
# 34  37119              3
# 35  38017              1
# 36  39081              1
# 37  41025              1
# 38  41029              1
# 39  41033              1
# 40  41035              1
# 41  41037              1
# 42  47037              2
# 43  47093              3
# 44  48037              1
# 45  48203              1
# 46  48273              1
# 47  48479              1
# 48  49035              6
# 49  53065              1
# 50  53077              2
# 51  54003              1

# %%
'''# Spatial join: assign each monitor to a county
merged_df_2 = gpd.sjoin(valid, merged_df, how="left", predicate="within")

# Group by county and aggregate
monitor_counts = (
    merged_df_2.groupby("GEOID")
    .agg(
        monitor_count=('geometry', 'size'),         # Count of monitors
        valid_dv_max=('Valid DV ', 'max')          # Example: max Valid DV per county
    )
    .reset_index()
)
monitor_counts'''
# Out:
# '# Spatial join: assign each monitor to a county\nmerged_df_2 = gpd.sjoin(valid, merged_df, how="left", predicate="within")\n\n# Group by county and aggregate\nmonitor_counts = (\n    merged_df_2.groupby("GEOID")\n    .agg(\n        monitor_count=(\'geometry\', \'size\'),         # Count of monitors\n        valid_dv_max=(\'Valid DV \', \'max\')          # Example: max Valid DV per county\n    )\n    .reset_index()\n)\nmonitor_counts'

# %%
# Merge monitor counts into counties GeoDataFrame
counties_with_monitor_counts = FN.merge(monitor_counts, on="GEOID", how="left")

# Fill NaNs (counties with 0 monitors)
counties_with_monitor_counts['monitor_count'] = counties_with_monitor_counts['monitor_count'].fillna(1).astype(int)
counties_with_monitor_counts
# Out:
#     index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  Design Value  \
# 0     108  20209   9.000000      20      209        172  20_209           9.6
# 1     112  47037   8.983334      47      037        182  47_037           9.6
# 2     114  26081   8.966666      26      081        187  26_081           9.3
# 3     115  22121   8.966666      22      121        187  22_121           9.1
# 4     116  28035   8.966666      28      035        187  28_035           9.2
# 5     119  37119   8.933333      37      119        196  37_119           9.2
# 6     124  30053   8.900001      30      053        205  30_053          12.8
# 7     125  18141   8.866667      18      141        210  18_141           9.4
# 8     127  13245   8.866667      13      245        210  13_245           9.7
# 9     128  06013   8.866666      06      013        217  06_013           9.6
# 10    131  47093   8.833333      47      093        221  47_093           9.1
# 11    134  34039   8.833333      34      039        221  34_039           9.4
# 12    137  13021   8.800000      13      021        236  13_021           9.4
# 13    143  04021   8.766666      04      021        245  04_021          10.4
# 14    146  49035   8.750000      49      035        260  49_035           9.3
# 15    148  26161   8.733334      26      161        261  26_161           9.3
# 16    151  05139   8.700000      05      139        273  05_139           9.3
# 17    155  19045   8.666667      19      045        282  19_045           9.2
# 18    160  48479   8.633333      48      479        298  48_479           9.7
# 19    162  34007   8.633333      34      007        298  34_007           9.8
# 20    163  18167   8.633333      18      167        298  18_167           9.5
# 21    172  48203   8.566667      48      203        329  48_203           9.5
# 22    179  48037   8.533334      48      037        351  48_037          10.3
# 23    185  41029   8.533333      41      029        375  41_029          10.5
# 24    200  26077   8.466666      26      077        422  26_077          10.4
# 25    201  39081   8.466666      39      081        422  39_081          10.0
# 26    202  06101   8.466666      06      101        422  06_101          11.2
# 27    207  28049   8.433333      28      049        442  28_049           9.3
# 28    238  30063   8.300000      30      063        565  30_063          10.5
# 29    256  01113   8.200000      01      113        668  01_113           9.5
# 30    274  41035   8.100000      41      035        760  41_035          12.0
# 31    276  53065   8.100000      53      065        760  53_065          10.1
# 32    278  20133   8.100000      20      133        769  20_133           9.3
# 33    291  37057   8.000000      37      057        855  37_057           9.2
# 34    292  41033   8.000000      41      033        855  41_033          10.2
# 35    297  54003   7.966667      54      003        899  54_003           9.1
# 36    300  06085   7.933333      06      085        926  06_085           9.1
# 37    315  13295   7.833333      13      295       1045  13_295          10.0
# 38    316  53077   7.833333      53      077       1045  53_077          10.2
# 39    317  06045   7.833333      06      045       1045  06_045          11.0
# 40    325  06071   7.766666      06      071       1125  06_071          13.1
# 41    328  13303   7.766666      13      303       1125  13_303          10.0
# 42    341  48273   7.666667      48      273       1230  48_273           9.9
# 43    351  16059   7.566667      16      059       1347  16_059          10.2
# 44    357  21013   7.533333      21      013       1391  21_013           9.1
# 45    397  16079   7.233334      16      079       1805  16_079          10.3
# 46    406  41037   7.133333      41      037       1932  41_037           9.1
# 47    416  26113   6.966667      26      113       2097  26_113           9.4
# 48    454  41025   6.633333      41      025       2415  41_025          10.0
# 49    455  38017   6.633333      38      017       2415  38_017           9.2
# 50    477  16009   6.400000      16      009       2589  16_009           9.9
# 51    523  04023   5.100000      04      023       3023  04_023           9.4
#
#                                              geometry      diff  \
# 0   POLYGON ((-94.90883 39.04342, -94.9088 39.0579... -0.600000
# 1   MULTIPOLYGON (((-86.52256 36.14128, -86.52106 ... -0.616666
# 2   POLYGON ((-85.79061 43.20987, -85.79056 43.226... -0.333334
# 3   POLYGON ((-91.48156 30.49742, -91.48173 30.511... -0.133334
# 4   POLYGON ((-89.45162 31.43403, -89.44455 31.434... -0.233334
# 5   POLYGON ((-81.05803 35.07319, -81.05768 35.078... -0.266667
# 6   POLYGON ((-116.04914 48.50205, -116.04913 48.5... -3.899999
# 7   POLYGON ((-86.52648 41.65768, -86.52601 41.672... -0.533333
# 8   POLYGON ((-82.3503 33.3148, -82.33028 33.32901... -0.833333
# 9   POLYGON ((-122.42976 37.9654, -122.42904 37.96... -0.733334
# 10  POLYGON ((-84.27347 35.93928, -84.27155 35.942... -0.266667
# 11  POLYGON ((-74.46329 40.59919, -74.45988 40.600... -0.566667
# 12  POLYGON ((-83.892 32.83254, -83.89192 32.84835... -0.600000
# 13  POLYGON ((-112.20362 32.5382, -112.20361 32.53... -1.633334
# 14  POLYGON ((-112.26022 40.76909, -112.19598 40.8... -0.550000
# 15  POLYGON ((-84.13406 42.16925, -84.13365 42.177... -0.566666
# 16  POLYGON ((-92.98633 33.0977, -92.98591 33.1163... -0.600000
# 17  POLYGON ((-90.89894 41.91853, -90.89807 41.920... -0.533333
# 18  POLYGON ((-100.21217 28.19684, -100.11372 28.1... -1.066667
# 19  POLYGON ((-75.1373 39.88997, -75.13541 39.893,... -1.166667
# 20  POLYGON ((-87.62048 39.30713, -87.61261 39.308... -0.866667
# 21  POLYGON ((-94.70215 32.45613, -94.70197 32.467... -0.933333
# 22  POLYGON ((-94.74663 33.44192, -94.74681 33.450... -1.766666
# 23  POLYGON ((-123.231 42.00493, -123.23097 42.082... -1.966667
# 24  POLYGON ((-85.76596 42.27536, -85.76596 42.280... -1.933334
# 25  POLYGON ((-80.94173 40.4278, -80.94113 40.4438... -1.533334
# 26  POLYGON ((-121.94828 39.24177, -121.94737 39.2... -2.733334
# 27  POLYGON ((-90.72862 32.22512, -90.72788 32.226... -0.866667
# 28  POLYGON ((-114.7972 47.26892, -114.79543 47.26... -2.200000
# 29  POLYGON ((-85.4347 32.31761, -85.43384 32.3922... -1.300000
# 30  POLYGON ((-122.28997 42.12716, -122.28747 42.1... -3.900000
# 31  POLYGON ((-118.40241 48.02638, -118.40081 48.0... -2.000000
# 32  POLYGON ((-95.5259 37.6456, -95.52584 37.66019... -1.200000
# 33  POLYGON ((-80.48742 35.8336, -80.48251 35.8403... -1.200000
# 34  POLYGON ((-124.04198 42.38766, -124.03884 42.3... -2.200000
# 35  POLYGON ((-78.229 39.3919, -78.2273 39.395, -7... -1.133333
# 36  POLYGON ((-122.20259 37.36272, -122.20132 37.3... -1.166667
# 37  POLYGON ((-85.53409 34.62386, -85.4908 34.6694... -2.166667
# 38  POLYGON ((-121.52028 46.87918, -121.51326 46.8... -2.366667
# 39  POLYGON ((-124.02325 40.00128, -123.93545 40.0... -3.166667
# 40  POLYGON ((-117.80254 33.97555, -117.79111 33.9... -5.333334
# 41  POLYGON ((-83.07365 32.94656, -83.0707 32.9471... -2.233334
# 42  MULTIPOLYGON (((-97.3178 27.49456, -97.3159 27... -2.233333
# 43  POLYGON ((-114.81868 44.74882, -114.81757 44.7... -2.633333
# 44  POLYGON ((-83.95599 36.64383, -83.95639 36.644... -1.566667
# 45  POLYGON ((-116.3296 48.01772, -116.32774 48.01... -3.066666
# 46  POLYGON ((-121.3513 42.91999, -121.34932 43.08... -1.966667
# 47  POLYGON ((-85.3384 44.42538, -85.33427 44.4982... -2.433333
# 48  POLYGON ((-119.94344 42.75367, -119.94357 42.9... -3.366667
# 49  POLYGON ((-97.70538 47.04981, -97.70558 47.051... -2.566667
# 50  POLYGON ((-117.04007 47.36603, -117.03926 47.3... -3.500000
# 51  POLYGON ((-111.36692 31.52136, -111.33572 31.5... -4.300000
#
#    classification  cdve_diff  near_miss1  cdv_diff  near_miss2  monitor_count
# 0              FN   0.000000        True       0.6       False              1
# 1              FN   0.016666        True       0.6       False              2
# 2              FN   0.033334        True       0.3        True              1
# 3              FN   0.033334        True       0.1        True              1
# 4              FN   0.033334        True       0.2        True              1
# 5              FN   0.066667        True       0.2        True              3
# 6              FN   0.099999        True       3.8       False              1
# 7              FN   0.133333        True       0.4        True              1
# 8              FN   0.133333        True       0.7       False              1
# 9              FN   0.133334        True       0.6       False              2
# 10             FN   0.166667        True       0.1        True              3
# 11             FN   0.166667        True       0.4        True              2
# 12             FN   0.200000        True       0.4        True              2
# 13             FN   0.233334        True       1.4       False              3
# 14             FN   0.250000        True       0.3        True              6
# 15             FN   0.266666        True       0.3        True              1
# 16             FN   0.300000        True       0.3        True              1
# 17             FN   0.333333        True       0.2        True              2
# 18             FN   0.366667        True       0.7       False              1
# 19             FN   0.366667        True       0.8       False              2
# 20             FN   0.366667        True       0.5        True              1
# 21             FN   0.433333        True       0.5        True              1
# 22             FN   0.466666        True       1.3       False              1
# 23             FN   0.466667        True       1.5       False              1
# 24             FN   0.533334       False       1.4       False              1
# 25             FN   0.533334       False       1.0       False              1
# 26             FN   0.533334       False       2.2       False              1
# 27             FN   0.566667       False       0.3        True              2
# 28             FN   0.700000       False       1.5       False              2
# 29             FN   0.800000       False       0.5        True              1
# 30             FN   0.900000       False       3.0       False              1
# 31             FN   0.900000       False       1.1       False              1
# 32             FN   0.900000       False       0.3        True              1
# 33             FN   1.000000       False       0.2        True              1
# 34             FN   1.000000       False       1.2       False              1
# 35             FN   1.033333       False       0.1        True              1
# 36             FN   1.066667       False       0.1        True              3
# 37             FN   1.166667       False       1.0       False              1
# 38             FN   1.166667       False       1.2       False              2
# 39             FN   1.166667       False       2.0       False              2
# 40             FN   1.233334       False       4.1       False              5
# 41             FN   1.233334       False       1.0       False              1
# 42             FN   1.333333       False       0.9       False              1
# 43             FN   1.433333       False       1.2       False              1
# 44             FN   1.466667       False       0.1        True              1
# 45             FN   1.766666       False       1.3       False              1
# 46             FN   1.866667       False       0.1        True              1
# 47             FN   2.033333       False       0.4        True              1
# 48             FN   2.366667       False       1.0       False              1
# 49             FN   2.366667       False       0.2        True              1
# 50             FN   2.600000       False       0.9       False              1
# 51             FN   3.900000       False       0.4        True              1

# %%
import matplotlib.pyplot as plt

# Color mapping
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Grouped scatter by classification
for label, group in counties_with_monitor_counts.groupby('classification'):
    plt.scatter(
        group['monitor_count'],
        group['diff'],
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Add horizontal line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('Number of Monitors in County', fontsize=13)
plt.ylabel('Difference (CDVE - CDV) (µg/m³)', fontsize=13)
plt.title('(a)', fontsize=14)

plt.grid(False)
#plt.legend(title='Classification')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define color mapping for classification
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Plot grouped by classification
for label, group in counties_with_monitor_counts.groupby('classification'):
    plt.scatter(
        group['Design Value'],     # x-axis
        group['diff'],             # y-axis
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Add horizontal line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('County Design Value (µg/m³)', fontsize=13)
plt.ylabel('Difference (CDVE - CDV) (µg/m³)', fontsize=13)
plt.title('(b)', fontsize=14)

plt.grid(False)
#plt.legend(title='Classification')
plt.tight_layout()
plt.show()

# %%
# Reproject to an equal-area CRS (if not already)
counties_with_monitor_counts = counties_with_monitor_counts.to_crs(epsg=5070)

# Compute area in square kilometers
counties_with_monitor_counts['area_km2'] = counties_with_monitor_counts.geometry.area / 1e6
counties_with_monitor_counts = counties_with_monitor_counts.to_crs(epsg=4269)

# %%
import matplotlib.pyplot as plt

# Define color mapping
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Scatter plot grouped by classification
for label, group in counties_with_monitor_counts.groupby('classification'):
    plt.scatter(
        group['area_km2'],         # x-axis
        group['diff'],             # y-axis
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Reference line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('County Area (km²)', fontsize=13)
plt.ylabel('Difference (CDVE – CDV) (µg/m³)', fontsize=13)
plt.title('(d)', fontsize=14)
plt.grid(False)

# Horizontal legend below
'''plt.legend(
    title='Classification',
    loc='lower center',
    bbox_to_anchor=(0.5, -0.25),
    ncol=4,
    frameon=False
)'''

plt.tight_layout()
plt.show()

# %%
removed = gpd.read_file('/data/acker/ALA/paper2/GL_removed_pixels_2021-2023_grids.shp')
removed
# Out:
#              removed        lat        lon  \
# 0          93.502815  14.195000 -90.525002
# 1         102.857147  14.195000 -90.514999
# 2         102.586212  14.195000 -90.504997
# 3          97.159096  14.195000 -90.495003
# 4          91.258743  14.205000 -90.574997
# ...              ...        ...        ...
# 2998275  1004.444397  67.985001 -50.055000
# 2998276  1023.333313  67.985001 -50.044998
# 2998277  1023.333313  67.985001 -50.035000
# 2998278  1029.444458  67.985001 -50.025002
# 2998279  1032.777710  67.985001 -50.014999
#
#                                                   geometry
# 0        POLYGON ((-90.525 14.195, -90.525 14.205, -90....
# 1        POLYGON ((-90.515 14.195, -90.515 14.205, -90....
# 2        POLYGON ((-90.505 14.195, -90.505 14.205, -90....
# 3        POLYGON ((-90.495 14.195, -90.495 14.205, -90....
# 4        POLYGON ((-90.575 14.205, -90.575 14.215, -90....
# ...                                                    ...
# 2998275  POLYGON ((-50.055 67.985, -50.055 67.995, -50....
# 2998276  POLYGON ((-50.045 67.985, -50.045 67.995, -50....
# 2998277  POLYGON ((-50.035 67.985, -50.035 67.995, -50....
# 2998278  POLYGON ((-50.025 67.985, -50.025 67.995, -50....
# 2998279  POLYGON ((-50.015 67.985, -50.015 67.995, -50....
#
# [2998280 rows x 4 columns]

# %%
rem_counties = gpd.sjoin(removed, counties_with_monitor_counts, how='inner', predicate='intersects')
rem_counties
# Out:
#             removed        lat         lon  \
# 6954     104.647438  19.395000 -155.604996
# 6955      93.888893  19.395000 -155.595001
# 6956      91.875000  19.405001 -155.634995
# 6957      93.333336  19.405001 -155.625000
# 6958      93.333336  19.405001 -155.615005
# ...             ...        ...         ...
# 1899193   90.797546  65.205002 -147.994995
# 1899194   91.411041  65.205002 -147.985001
# 1899195   93.827148  65.205002 -147.975006
# 1899196   92.024544  65.205002 -147.964996
# 1899197   91.411041  65.205002 -147.955002
#
#                                                   geometry  index_right0  \
# 6954     POLYGON ((-155.605 19.395, -155.605 19.405, -1...           533
# 6955     POLYGON ((-155.595 19.395, -155.595 19.405, -1...           533
# 6956     POLYGON ((-155.63499 19.405, -155.63499 19.415...           533
# 6957     POLYGON ((-155.625 19.405, -155.625 19.415, -1...           533
# 6958     POLYGON ((-155.61501 19.405, -155.61501 19.415...           533
# ...                                                    ...           ...
# 1899193  POLYGON ((-147.995 65.205, -147.995 65.215, -1...             0
# 1899194  POLYGON ((-147.985 65.205, -147.985 65.215, -1...             0
# 1899195  POLYGON ((-147.97501 65.205, -147.97501 65.215...             0
# 1899196  POLYGON ((-147.965 65.205, -147.965 65.215, -1...             0
# 1899197  POLYGON ((-147.955 65.205, -147.955 65.215, -1...             0
#
#          index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  \
# 6954       533  15001   3.633333      15      001       3133  15_001
# 6955       533  15001   3.633333      15      001       3133  15_001
# 6956       533  15001   3.633333      15      001       3133  15_001
# 6957       533  15001   3.633333      15      001       3133  15_001
# 6958       533  15001   3.633333      15      001       3133  15_001
# ...        ...    ...        ...     ...      ...        ...     ...
# 1899193      0  02090  14.333333      02      090          1  02_090
# 1899194      0  02090  14.333333      02      090          1  02_090
# 1899195      0  02090  14.333333      02      090          1  02_090
# 1899196      0  02090  14.333333      02      090          1  02_090
# 1899197      0  02090  14.333333      02      090          1  02_090
#
#          Design Value      diff classification  monitor_count
# 6954              4.4 -0.766667             TN              5
# 6955              4.4 -0.766667             TN              5
# 6956              4.4 -0.766667             TN              5
# 6957              4.4 -0.766667             TN              5
# 6958              4.4 -0.766667             TN              5
# ...               ...       ...            ...            ...
# 1899193          12.1  2.233333             TP              3
# 1899194          12.1  2.233333             TP              3
# 1899195          12.1  2.233333             TP              3
# 1899196          12.1  2.233333             TP              3
# 1899197          12.1  2.233333             TP              3
#
# [144433 rows x 16 columns]

# %%
total_removed_per_county = rem_counties.groupby('GEOID').size().reset_index(name='removed_grids')
final_df_1 = counties_with_monitor_counts.merge(total_removed_per_county, on='GEOID', how='left')
final_df_1
# Out:
#      index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  \
# 0        0  02090  14.333333      02      090          1  02_090
# 1        1  06063  14.200000      06      063          2  06_063
# 2        2  06107  12.933334      06      107          4  06_107
# 3        3  06023  12.633334      06      023          5  06_023
# 4        4  06029  12.599999      06      029          6  06_029
# ..     ...    ...        ...     ...      ...        ...     ...
# 531    531  02020   4.133333      02      020       3118  02_020
# 532    532  02110   3.900000      02      110       3128  02_110
# 533    533  15001   3.633333      15      001       3133  15_001
# 534    534  15009   3.556667      15      009       3136  15_009
# 535    535  15003   3.100000      15      003       3141  15_003
#
#      Design Value                                           geometry  \
# 0            12.1  POLYGON ((-148.66326 64.59079, -148.64821 64.5...
# 1            14.0  POLYGON ((-121.49703 40.43702, -121.49487 40.4...
# 2            15.7  POLYGON ((-119.56647 36.49434, -119.56366 36.4...
# 3             6.9  POLYGON ((-124.4086 40.4432, -124.39664 40.462...
# 4            16.2  POLYGON ((-120.19437 35.78936, -120.00308 35.7...
# ..            ...                                                ...
# 531           5.1  MULTIPOLYGON (((-150.07348 61.15834, -150.0691...
# 532           4.6  MULTIPOLYGON (((-134.66932 58.33327, -134.6675...
# 533           4.4  POLYGON ((-156.06147 19.72813, -156.06076 19.7...
# 534           4.0  MULTIPOLYGON (((-156.69742 20.91637, -156.6957...
# 535           3.7  MULTIPOLYGON (((-157.65982 21.32857, -157.6588...
#
#          diff classification  monitor_count  removed_grids
# 0    2.233333             TP              3         4254.0
# 1    0.200000             TP              1          636.0
# 2   -2.766666             TP              1         1365.0
# 3    5.733334             FN              1          680.0
# 4   -3.600001             TP              5            NaN
# ..        ...            ...            ...            ...
# 531 -0.966667             TN              1         3534.0
# 532 -0.700000             TN              1         7984.0
# 533 -0.766667             TN              5           72.0
# 534 -0.443333             TN              1          141.0
# 535 -0.600000             TN              3           18.0
#
# [536 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Define color mapping
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Scatter plot grouped by classification
for label, group in final_df_1.groupby('classification'):
    plt.scatter(
        group['removed_grids'],         # x-axis
        group['diff'],             # y-axis
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Reference line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('# of High Uncertainty Grids Removed', fontsize=13)
plt.ylabel('Difference (CDVE – CDV) (µg/m³)', fontsize=13)
plt.title('(e)', fontsize=14)
plt.grid(False)

# Horizontal legend below
'''plt.legend(
    title='Classification',
    loc='lower center',
    bbox_to_anchor=(0.5, -0.25),
    ncol=4,
    frameon=False
)'''

plt.tight_layout()
plt.show()

# %%
df = gpd.read_file('/data/acker/ALA/paper2/GL_2021-2023_grids.shp')
df
# Out:
#               value        lat        lon  \
# 0         15.533333  10.005000 -85.724998
# 1         15.666667  10.005000 -85.714996
# 2         15.666667  10.005000 -85.705002
# 3         14.700000  10.005000 -85.695000
# 4         14.266666  10.005000 -85.684998
# ...             ...        ...        ...
# 25002341   1.400000  67.985001 -51.395000
# 25002342   1.400000  67.985001 -51.384998
# 25002343   1.400000  67.985001 -51.375000
# 25002344   1.400000  67.985001 -51.355000
# 25002345   1.400000  67.985001 -51.345001
#
#                                                    geometry
# 0         POLYGON ((-85.725 10.005, -85.725 10.015, -85....
# 1         POLYGON ((-85.715 10.005, -85.715 10.015, -85....
# 2         POLYGON ((-85.705 10.005, -85.705 10.015, -85....
# 3         POLYGON ((-85.695 10.005, -85.695 10.015, -85....
# 4         POLYGON ((-85.685 10.005, -85.685 10.015, -85....
# ...                                                     ...
# 25002341  POLYGON ((-51.395 67.985, -51.395 67.995, -51....
# 25002342  POLYGON ((-51.385 67.985, -51.385 67.995, -51....
# 25002343  POLYGON ((-51.375 67.985, -51.375 67.995, -51....
# 25002344  POLYGON ((-51.355 67.985, -51.355 67.995, -51....
# 25002345  POLYGON ((-51.345 67.985, -51.345 67.995, -51....
#
# [25002346 rows x 4 columns]

# %%
df = df.to_crs(epsg=4269)

# %%
joined = gpd.sjoin(df, counties_with_monitor_counts, how='left', predicate='intersects')
joined
# Out:
#               value        lat        lon  \
# 0         15.533333  10.005000 -85.724998
# 1         15.666667  10.005000 -85.714996
# 2         15.666667  10.005000 -85.705002
# 3         14.700000  10.005000 -85.695000
# 4         14.266666  10.005000 -85.684998
# ...             ...        ...        ...
# 25002341   1.400000  67.985001 -51.395000
# 25002342   1.400000  67.985001 -51.384998
# 25002343   1.400000  67.985001 -51.375000
# 25002344   1.400000  67.985001 -51.355000
# 25002345   1.400000  67.985001 -51.345001
#
#                                                    geometry  index_right0  \
# 0         POLYGON ((-85.725 10.005, -85.725 10.015, -85....           NaN
# 1         POLYGON ((-85.715 10.005, -85.715 10.015, -85....           NaN
# 2         POLYGON ((-85.705 10.005, -85.705 10.015, -85....           NaN
# 3         POLYGON ((-85.695 10.005, -85.695 10.015, -85....           NaN
# 4         POLYGON ((-85.685 10.005, -85.685 10.015, -85....           NaN
# ...                                                     ...           ...
# 25002341  POLYGON ((-51.395 67.985, -51.395 67.995, -51....           NaN
# 25002342  POLYGON ((-51.385 67.985, -51.385 67.995, -51....           NaN
# 25002343  POLYGON ((-51.375 67.985, -51.375 67.995, -51....           NaN
# 25002344  POLYGON ((-51.355 67.985, -51.355 67.995, -51....           NaN
# 25002345  POLYGON ((-51.345 67.985, -51.345 67.995, -51....           NaN
#
#           index GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank   ID  \
# 0           NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 1           NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 2           NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 3           NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 4           NaN   NaN        NaN     NaN      NaN        NaN  NaN
# ...         ...   ...        ...     ...      ...        ...  ...
# 25002341    NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 25002342    NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 25002343    NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 25002344    NaN   NaN        NaN     NaN      NaN        NaN  NaN
# 25002345    NaN   NaN        NaN     NaN      NaN        NaN  NaN
#
#           Design Value  diff classification  cdve_diff near_miss1  cdv_diff  \
# 0                  NaN   NaN            NaN        NaN        NaN       NaN
# 1                  NaN   NaN            NaN        NaN        NaN       NaN
# 2                  NaN   NaN            NaN        NaN        NaN       NaN
# 3                  NaN   NaN            NaN        NaN        NaN       NaN
# 4                  NaN   NaN            NaN        NaN        NaN       NaN
# ...                ...   ...            ...        ...        ...       ...
# 25002341           NaN   NaN            NaN        NaN        NaN       NaN
# 25002342           NaN   NaN            NaN        NaN        NaN       NaN
# 25002343           NaN   NaN            NaN        NaN        NaN       NaN
# 25002344           NaN   NaN            NaN        NaN        NaN       NaN
# 25002345           NaN   NaN            NaN        NaN        NaN       NaN
#
#          near_miss2  monitor_count
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 25002341        NaN            NaN
# 25002342        NaN            NaN
# 25002343        NaN            NaN
# 25002344        NaN            NaN
# 25002345        NaN            NaN
#
# [25002996 rows x 20 columns]

# %%
grids = joined.dropna(subset=['value','GEOID'])

# %%
grids = grids.drop(columns=['index_right0'])

# %%
monitors_with_grid = gpd.sjoin(valid, grids, how="inner", predicate="within")

# Now each monitor has the grid cell + county info it falls within

# %%
total_grids_per_county = grids.groupby('GEOID').size().reset_index(name='total_grids')

# %%
# Keep unique grid geometries with monitors
grids_with_monitor = monitors_with_grid.drop_duplicates(subset='geometry')

# Count how many unique grid cells have a monitor in each county
monitor_grids_per_county = grids_with_monitor.groupby('GEOID').size().reset_index(name='grids_with_monitor')

# %%
coverage_df = total_grids_per_county.merge(monitor_grids_per_county, on='GEOID', how='left')
coverage_df['grids_with_monitor'] = coverage_df['grids_with_monitor'].fillna(0)

coverage_df['monitor_coverage_pct'] = 100 * coverage_df['grids_with_monitor'] / coverage_df['total_grids']

# %%
coverage_df['monitor_coverage_pct'].describe()
# Out:
# count    45.000000
# mean      0.155546
# std       0.180404
# min       0.000000
# 25%       0.059773
# 50%       0.086430
# 75%       0.141376
# max       0.833333
# Name: monitor_coverage_pct, dtype: float64

# %%
final_df = counties_with_monitor_counts.merge(coverage_df, on='GEOID', how='left')

final_df
# Out:
#     index  GEOID  PM25_90th STATEFP COUNTYFP  CDVE_rank      ID  Design Value  \
# 0       3  06023  12.633334      06      023          5  06_023           6.9
# 1      16  28047  10.666667      28      047         21  28_047           8.0
# 2      23  06103  10.500000      06      103         29  06_103           7.5
# 3      28  22071  10.400001      22      071         34  22_071           7.8
# 4      31  06007  10.233334      06      007         38  06_007           8.9
# 5      32  40143  10.200000      40      143         40  40_143           8.8
# 6      35  22051  10.033333      22      051         45  22_051           7.7
# 7      39  34017   9.823333      34      017         56  34_017           7.8
# 8      40  24005   9.820000      24      005         57  24_005           8.3
# 9      41  48121   9.800000      48      121         58  48_121           7.7
# 10     46  13063   9.733334      13      063         65  13_063           8.9
# 11     50  26099   9.700000      26      099         68  26_099           8.7
# 12     53  28059   9.633333      28      059         77  28_059           7.6
# 13     57  36061   9.566667      36      061         83  36_061           7.8
# 14     59  22109   9.533334      22      109         87  22_109           7.9
# 15     60  29189   9.510000      29      189         89  29_189           7.2
# 16     61  28045   9.500000      28      045         90  28_045           7.8
# 17     62  13089   9.500000      13      089         90  13_089           8.7
# 18     64  30029   9.466666      30      029         98  30_029           8.6
# 19     65  22087   9.433333      22      087         99  22_087           8.2
# 20     66  13067   9.433333      13      067         99  13_067           8.9
# 21     69  34003   9.400001      34      003        103  34_003           8.5
# 22     71  36047   9.390000      36      047        109  36_047           8.0
# 23     73  12057   9.366666      12      057        112  12_057           7.4
# 24     75  48029   9.333333      48      029        114  48_029           8.9
# 25     76  42095   9.333333      42      095        114  42_095           8.3
# 26     77  47065   9.333333      47      065        114  47_065           8.4
# 27     78  12103   9.300000      12      103        122  12_103           6.9
# 28     80  48141   9.300000      48      141        122  48_141           9.0
# 29     82  54029   9.300000      54      029        122  54_029           8.3
# 30     87  42007   9.233334      42      007        136  42_007           8.9
# 31     89  19163   9.233334      19      163        136  19_163           8.9
# 32     90  47157   9.200000      47      157        139  47_157           8.9
# 33     91  45045   9.200000      45      045        139  45_045           8.4
# 34     93  49011   9.160000      49      011        147  49_011           7.3
# 35     94  39113   9.133334      39      113        149  39_113           9.0
# 36     95  06057   9.133334      06      057        149  06_057           6.5
# 37     96  36081   9.133333      36      081        152  36_081           8.1
# 38     97  54009   9.133333      54      009        152  54_009           8.7
# 39     98  27123   9.133333      27      123        152  27_123           9.0
# 40     99  55009   9.099999      55      009        158  55_009           7.7
# 41    102  42075   9.066667      42      075        162  42_075           8.4
# 42    103  17111   9.066667      17      111        162  17_111           8.9
# 43    104  39153   9.066667      39      153        162  39_153           8.6
# 44    107  16027   9.033334      16      027        166  16_027           8.9
#
#                                              geometry      diff  \
# 0   POLYGON ((-124.4086 40.4432, -124.39664 40.462...  5.733334
# 1   MULTIPOLYGON (((-88.86677 30.38297, -88.8655 3...  2.666667
# 2   POLYGON ((-123.06543 40.28697, -123.06073 40.2...  3.000000
# 3   POLYGON ((-90.14007 29.9479, -90.1376 29.95149...  2.600001
# 4   POLYGON ((-122.06874 39.84222, -122.06694 39.8...  1.333334
# 5   POLYGON ((-96.29791 36.07605, -96.2979 36.1048...  1.400000
# 6   MULTIPOLYGON (((-89.95023 29.27704, -89.94302 ...  2.333333
# 7   MULTIPOLYGON (((-74.0422 40.69997, -74.039 40....  2.023333
# 8   MULTIPOLYGON (((-76.3257 39.31397, -76.32452 3...  1.520000
# 9   POLYGON ((-97.39826 32.99996, -97.39792 33.013...  2.100000
# 10  POLYGON ((-84.45893 33.56541, -84.45863 33.572...  0.833334
# 11  POLYGON ((-83.10289 42.88865, -83.04297 42.890...  1.000000
# 12  MULTIPOLYGON (((-88.50502 30.21574, -88.49164 ...  2.033333
# 13  MULTIPOLYGON (((-74.00542 40.69016, -74.00488 ...  1.766667
# 14  MULTIPOLYGON (((-90.41444 29.20798, -90.4123 2...  1.633334
# 15  POLYGON ((-90.73651 38.46813, -90.73643 38.469...  2.310000
# 16  POLYGON ((-89.68416 30.45915, -89.67723 30.459...  1.700000
# 17  POLYGON ((-84.34981 33.66384, -84.3498 33.6640...  0.800000
# 18  POLYGON ((-115.02008 48.22595, -114.98694 48.2...  0.866666
# 19  MULTIPOLYGON (((-88.8677 29.86155, -88.86566 2...  1.233333
# 20  POLYGON ((-84.7394 33.95908, -84.73946 33.9655...  0.533333
# 21  POLYGON ((-74.27066 41.02103, -74.26299 41.036...  0.900001
# 22  POLYGON ((-74.04171 40.62638, -74.04166 40.626...  1.390000
# 23  MULTIPOLYGON (((-82.42055 27.84654, -82.4146 2...  1.966666
# 24  POLYGON ((-98.80655 29.69071, -98.80277 29.694...  0.433333
# 25  POLYGON ((-75.60805 40.78748, -75.60261 40.788...  1.033333
# 26  POLYGON ((-85.47489 34.98697, -85.46845 34.986...  0.933333
# 27  MULTIPOLYGON (((-82.69547 27.66549, -82.69391 ...  2.400000
# 28  POLYGON ((-106.64548 31.89867, -106.64084 31.9...  0.300000
# 29  POLYGON ((-80.66796 40.5825, -80.66589 40.5877...  1.000000
# 30  POLYGON ((-80.51909 40.59227, -80.51909 40.616...  0.333334
# 31  POLYGON ((-90.8998 41.5986, -90.89976 41.60069...  0.333334
# 32  POLYGON ((-90.31045 35.0027, -90.30926 35.0095...  0.300000
# 33  POLYGON ((-82.7641 35.06817, -82.7577 35.06802...  0.800000
# 34  POLYGON ((-112.45162 41.08733, -112.19934 41.1...  1.860000
# 35  POLYGON ((-84.48537 39.91849, -84.48298 39.918...  0.133334
# 36  POLYGON ((-121.27975 39.10985, -121.27959 39.1...  2.633334
# 37  POLYGON ((-73.96262 40.73903, -73.96244 40.739...  1.033333
# 38  POLYGON ((-80.68181 40.18557, -80.6796 40.1863...  0.433333
# 39  POLYGON ((-93.22797 45.11622, -93.22779 45.116...  0.133333
# 40  MULTIPOLYGON (((-87.98927 44.60464, -87.98322 ...  1.399999
# 41  POLYGON ((-76.67804 40.47472, -76.53541 40.555...  0.666667
# 42  POLYGON ((-88.70738 42.49359, -88.6708 42.4943...  0.166667
# 43  POLYGON ((-81.68825 40.99911, -81.68815 41.004...  0.466667
# 44  POLYGON ((-117.03189 43.83416, -117.02516 43.8...  0.133334
#
#    classification  cdve_diff  near_miss1  cdv_diff  near_miss2  monitor_count  \
# 0              FN   3.633334       False       2.1       False              1
# 1              FN   1.666667       False       1.0       False              1
# 2              FN   1.500000       False       1.5       False              1
# 3              FN   1.400001       False       1.2       False              1
# 4              FN   1.233334       False       0.1        True              1
# 5              FN   1.200000       False       0.2        True              1
# 6              FN   1.033333       False       1.3       False              2
# 7              FN   0.823333       False       1.2       False              1
# 8              FN   0.820000       False       0.7       False              2
# 9              FN   0.800000       False       1.3       False              1
# 10             FN   0.733334       False       0.1        True              1
# 11             FN   0.700000       False       0.3        True              1
# 12             FN   0.633333       False       1.4       False              1
# 13             FN   0.566667       False       1.2       False              1
# 14             FN   0.533334       False       1.1       False              1
# 15             FN   0.510000       False       1.8       False              1
# 16             FN   0.500000        True       1.2       False              1
# 17             FN   0.500000        True       0.3        True              1
# 18             FN   0.466666        True       0.4        True              1
# 19             FN   0.433333        True       0.8       False              1
# 20             FN   0.433333        True       0.1        True              1
# 21             FN   0.400001        True       0.5        True              1
# 22             FN   0.390000        True       1.0       False              1
# 23             FN   0.366666        True       1.6       False              2
# 24             FN   0.333333        True       0.1        True              3
# 25             FN   0.333333        True       0.7       False              1
# 26             FN   0.333333        True       0.6       False              1
# 27             FN   0.300000        True       2.1       False              2
# 28             FN   0.300000        True       0.0        True              1
# 29             FN   0.300000        True       0.7       False              1
# 30             FN   0.233334        True       0.1        True              1
# 31             FN   0.233334        True       0.1        True              2
# 32             FN   0.200000        True       0.1        True              3
# 33             FN   0.200000        True       0.6       False              2
# 34             FN   0.160000        True       1.7       False              1
# 35             FN   0.133334        True       0.0        True              1
# 36             FN   0.133334        True       2.5       False              1
# 37             FN   0.133333        True       0.9       False              2
# 38             FN   0.133333        True       0.3        True              2
# 39             FN   0.133333        True       0.0        True              2
# 40             FN   0.099999        True       1.3       False              1
# 41             FN   0.066667        True       0.6       False              1
# 42             FN   0.066667        True       0.1        True              1
# 43             FN   0.066667        True       0.4        True              1
# 44             FN   0.033334        True       0.1        True              1
#
#         area_km2  total_grids  grids_with_monitor  monitor_coverage_pct
# 0    9351.972148        10107                 1.0              0.009894
# 1    1524.637777         1529                 1.0              0.065402
# 2    7673.003672         8387                 1.0              0.011923
# 3     901.396540          618                 0.0              0.000000
# 4    4343.959600         4777                 1.0              0.020934
# 5    1519.845735         1606                 1.0              0.062267
# 6    1321.418938         1033                 3.0              0.290416
# 7     135.745324          195                 1.0              0.512821
# 8    1608.946974         1842                 2.0              0.108578
# 9    2464.738948         2421                 1.0              0.041305
# 10    373.828845          437                 1.0              0.228833
# 11   1253.772350         1466                 1.0              0.068213
# 12   1932.310737         1894                 1.0              0.052798
# 13     82.132710          120                 1.0              0.833333
# 14   3847.781097         3624                 1.0              0.027594
# 15   1355.069610         1534                 2.0              0.130378
# 16   1251.417668         1269                 1.0              0.078802
# 17    702.263934          758                 1.0              0.131926
# 18  13613.077005        16799                 1.0              0.005953
# 19   1597.767614         1589                 1.0              0.062933
# 20    892.284698          941                 1.0              0.106270
# 21    638.252762          767                 1.0              0.130378
# 22    205.476214          246                 1.0              0.406504
# 23   2801.499849         2673                 2.0              0.074822
# 24   3253.274907         3186                 3.0              0.094162
# 25    976.882103         1157                 1.0              0.086430
# 26   1490.941606         1592                 2.0              0.125628
# 27    843.842181          863                 2.0              0.231750
# 28   2629.049086         2630                 2.0              0.076046
# 29    227.901622          283                 1.0              0.353357
# 30   1150.073561         1288                 1.0              0.077640
# 31   1212.713670         1410                 2.0              0.141844
# 32   2021.103347         2122                 3.0              0.141376
# 33   2060.693438         2193                 2.0              0.091199
# 34   1645.243440          726                 1.0              0.137741
# 35   1202.425546         1335                 1.0              0.074906
# 36   2521.995642         2824                 1.0              0.035411
# 37    318.829277          400                 2.0              0.500000
# 38    239.974371          297                 2.0              0.673401
# 39    440.318724          559                 2.0              0.357782
# 40   1385.377153         1673                 1.0              0.059773
# 41    938.924698         1084                 1.0              0.092251
# 42   1583.226057         1833                 1.0              0.054555
# 43   1088.152720         1267                 1.0              0.078927
# 44   1563.380207         1883                 1.0              0.053107

# %%
import matplotlib.pyplot as plt

# Define color mapping for classification
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Scatter plot grouped by classification
for label, group in final_df.groupby('classification'):
    plt.scatter(
        group['monitor_coverage_pct'],  # x-axis
        group['diff'],                  # y-axis
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Add horizontal line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('% of County Grid Cells with Monitor', fontsize=13)
plt.ylabel('Difference (CDVE – CDV) (µg/m³)', fontsize=13)
plt.title('(c)', fontsize=14)
plt.grid(False)
plt.legend(title='Classification')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define color mapping for classification
colors = {
    'TP': 'green',
    'FP': 'red',
    'FN': 'orange',
    'TN': 'blue'
}

plt.figure(figsize=(8, 6))

# Scatter plot grouped by classification
for label, group in final_df.groupby('classification'):
    plt.scatter(
        group['monitor_coverage_pct'],  # x-axis
        group['diff'],                  # y-axis
        alpha=0.7,
        edgecolors='k',
        label=label,
        color=colors.get(label, 'gray')
    )

# Add horizontal line at y = 0
plt.axhline(0, linestyle='--', color='black')

# Labels and formatting
plt.rcParams["font.family"] = "serif"
plt.xlabel('% of County Grid Cells with Monitor', fontsize=13)
plt.ylabel('Difference (CDVE – CDV) (µg/m³)', fontsize=13)
plt.title('(c)', fontsize=14)
plt.grid(False)

# Horizontal legend below plot
plt.legend(
    title=None,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.2),
    ncol=4,
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
merged_df_2 = merged_df_2.to_crs(epsg=5070)
highest_monitor = (
    merged_df_2.sort_values('Valid DV ', ascending=False)
    .drop_duplicates('GEOID')
    .rename(columns={'geometry': 'monitor_geom'})
    [['GEOID', 'Valid DV ', 'monitor_geom']]
)

# %%
grids.columns
# Out:
# Index(['value', 'lat', 'lon', 'geometry', 'index', 'GEOID', 'PM25_90th',
#        'STATEFP', 'COUNTYFP', 'CDVE_rank', 'ID', 'Design Value', 'diff',
#        'classification', 'cdve_diff', 'near_miss1', 'cdv_diff', 'near_miss2',
#        'monitor_count'],
#       dtype='object')

# %%
grids = grids.to_crs(epsg=5070)
highest_grid = (
    grids.sort_values('PM25_90th', ascending=False)
    .drop_duplicates('GEOID')
    .rename(columns={'geometry': 'grid_geom'})
    [['GEOID', 'PM25_90th', 'grid_geom']]
)

# %%
from shapely.geometry import Point

# Merge the two
comparison_df = highest_monitor.merge(highest_grid, on='GEOID', how='inner')

# Calculate distance in kilometers
comparison_df['dist_km'] = comparison_df.apply(
    lambda row: row['monitor_geom'].distance(row['grid_geom']) / 1000, axis=1
)

# %%
final_plot_df = counties_with_monitor_counts[['GEOID', 'diff','classification']].merge(
    comparison_df[['GEOID', 'dist_km']], on='GEOID', how='inner'
)

# %%
final_plot_df['dist_km'].describe()
# Out:
# count     52.000000
# mean      33.269942
# std       27.627874
# min        1.599057
# 25%       15.420190
# 50%       25.660607
# 75%       42.732398
# max      134.852208
# Name: dist_km, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Filter only False Negatives
fn_df = final_plot_df[final_plot_df['classification'] == 'FN'].copy()

# Define distance bins (e.g., every 5 km up to 50+ km)
bins = [0, 5, 10, 15, 20, 30, 50, np.inf]
labels = ['0–5', '5–10', '10–15', '15–20', '20–30', '30–50', '50+']

# Assign each FN county to a distance bin
fn_df['dist_bin'] = pd.cut(fn_df['dist_km'], bins=bins, labels=labels, right=False)

# Prepare boxplot data
boxplot_data = [fn_df[fn_df['dist_bin'] == label]['diff'] for label in labels]

# Plot
plt.figure(figsize=(8, 6))
plt.boxplot(boxplot_data, labels=labels, patch_artist=True,
            boxprops=dict(facecolor='#fe9bfe', color='black'),
            medianprops=dict(color='black'),
            whiskerprops=dict(color='black'),
            capprops=dict(color='black'))

# Labels and formatting
plt.axhline(0, linestyle='--', color='black')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(-6,6)
plt.xlabel('Distance Bin (km)', fontsize=13)
plt.ylabel('', fontsize=13)
plt.title('(d) False Negatives', fontsize=18)
plt.rcParams["font.family"] = "serif"
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
# Group by distance bin and calculate summary statistics
stats_df = (
    fn_df.groupby('dist_bin')['diff']
    .agg(
        count='count',
        mean='mean',
        std='std',
        min='min',
        max='max',
        median='median'
    )
    .reset_index()
)

# Add range as a new column
stats_df['range'] = stats_df['max'] - stats_df['min']

# Sort by count or range if you want to identify which is largest
stats_df_sorted_by_range = stats_df.sort_values('range', ascending=False)
stats_df_sorted_by_count = stats_df.sort_values('count', ascending=False)

# Display the full table
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)  # Format for cleaner output
print(stats_df)
# Out:
#   dist_bin  count  mean  std  min  max  median  range
# 0      0–5      4  1.11 0.80 0.13 2.02    1.15   1.89
# 1     5–10      7  0.90 0.54 0.17 1.77    0.83   1.60
# 2    10–15      7  1.00 0.63 0.30 2.10    1.03   1.80
# 3    15–20      6  1.24 1.04 0.13 2.60    1.00   2.47
# 4    20–30     10  2.06 1.52 0.47 5.73    2.00   5.27
# 5    30–50      9  1.37 1.00 0.13 3.00    1.33   2.87
# 6      50+      2  1.25 0.54 0.87 1.63    1.25   0.77
# /tmp/ipykernel_2871/672414962.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fn_df.groupby('dist_bin')['diff']
